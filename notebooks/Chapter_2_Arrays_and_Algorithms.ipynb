// %% [markdown]
// # Chapter 2 — Arrays and Algorithms
//
// ## 2.1 Why We Need Arrays
//
// In many engineering problems, we do not work with a single value!!
//
// Instead, we work with **collections of related values**, such as:
// - sensor readings over time
// - sampled voltages or currents
// - temperatures from multiple locations
// - repeated measurements from an experiment
//
// In EE115 (Python), you worked with **lists** to store multiple values in one variable. For example, in Python you might have written:
// ```python
// voltages = [3.2, 3.1, 3.3, 3.0]
// ```
//
// Java provides a similar idea, but with arrays. Just like in Python, the Java arrays allow us to:
// - store many values of the same type
// - access them using an index
// - process them using loops
//
// ### Why Single Variables Don’t Scale
//
// Using separate variables quickly becomes impractical:
// ```java
// double v1 = 3.2;
// double v2 = 3.1;
// double v3 = 3.3;
// double v4 = 3.0;
// ```
//
// This approach:
// - does not scale
// - is hard to loop over
// - makes algorithms difficult to write
// - leads to repetitive code
//
// Arrays solve this problem by grouping related values into one structured variable. In the next sections, we will learn how to:
// - create arrays in Java
// - access and modify their elements
// - use loops to process them
// - implement simple algorithms using arrays

// %% [markdown]
// ## 2.2 Declaring and Creating Arrays
//
// In Java, an **array** is a fixed-size container that holds multiple values of the **same type**.
//
// This is similar to Python lists, but with some important differences that we will highlight as we go.
//
// Before we can use an array, we must:
// 1. declare it
// 2. create it
//
// ### Array Syntax in Java
//
// The general pattern for declaring an array is:
// ```java
//     type[] name;
// ```
// For example:
// - `int[]` means “array of integers”
// - `double[]` means “array of doubles”
// - `String[]` means “array of Strings”
//
// Declaring an array does **not** create it — it only creates a reference. Try running each Java cell below to get the idea.

// %%
// Declare an array of integers
int[] data;

// At this point, the array exists as a variable,
// but it does not yet contain any storage.
// No memory has been ring-fenced for it in your computer!

// %%
// If the memory has not been allocated 
// you cannot use the array!
int[] data;

// This line attempts to access element 0
// but no memory has been allocated yet
data[0] = 1;

// The code will CRASH!
// 'data' exists as a variable name, but it points to **nothing**.
// We must create the array before accessing its elements.

// %%
// Declare the array
int[] data;

// Create the array with space for 5 integers
data = new int[5];

// Now the array exists in memory,
// so accessing elements is safe
data[0] = 1;

// Print the value to confirm
System.out.println(data[0]);

// %% [markdown]
// ### Mental Model
//
// Think of it like this:
//
// - `int[] data;`
//   → creates a **label** or a **name**
//
// - `data = new int[5];`
//   → creates the **storage**
//
// Until both steps are done, the array cannot be used. This distinction will appear again later when we work with classes and objects. Understanding it now will make those topics much easier.
//
// ### One-Line Declaration and Creation
//
// It is very common to declare and create an array in a single line.

// %%
// Create an array of 5 integers
int[] data = new int[5];

// Print the length of the array
System.out.println(data.length);

// %% [markdown]
// ### Fixed Size Concept
//
// Once an array is created, its size is **fixed**.
//
// - You cannot change the length of an array
// - You must decide the size when creating it
// - This is different from Python lists, which can grow and shrink dynamically
//
// If you need a different size, you must create a **new array**.
//
// ### Default Values in Arrays
//
// When an array is created, Java automatically fills it with **default values**.
//
// For numeric types:
// - `int` → 0
// - `double` → 0.0
//
// For booleans:
// - `boolean` → false
//
// For objects (e.g. `String`):
// - default value → null

// %%
// Simple exampled: Default values in an int array
int[] numbers = new int[4];

System.out.println(numbers[0]);
System.out.println(numbers[1]);
System.out.println(numbers[2]);
System.out.println(numbers[3]);

// %%
//Exercise: try and write the four print statements above using a while loop

// %%
// Another example: Default values in a double array
double[] numbers = new double[4];

System.out.println(numbers[0]);
System.out.println(numbers[1]);
System.out.println(numbers[2]);
System.out.println(numbers[3]);

// %%
//Exercise: try and write the four print statements above using a for loop

// %%
// Yet another example! 
// Default values in a boolean array
boolean[] flags = new boolean[2];

System.out.println(flags[0]);
System.out.println(flags[1]);

// %% [markdown]
// ### Key Points
//
// - Arrays store multiple values of the same type
// - Arrays must be declared and then created
// - Array sizes are fixed once created
// - Java automatically assigns default values
//
// In the next section, we will learn how to **access and modify individual elements** using indexing.

// %% [markdown]
// ## 2.3 Array Indexing
//
// As you saw in several of the examples above, once an array has been created, we access individual elements using an **index**.
//
// Just like in Python, in Java:
// - Array indices start at **0**
// - The last index is **length − 1**
//
// For an array of size 5:
//
// Index:  0   1   2   3   4
// Size:   5 elements total
//
// This is exactly the same convention you used with lists in Python (and in nearly every language).
//
// And just like in Python we can assign the value by using the index!

// %%
// Create an array with 5 elements
int[] data = new int[5];

// Assign values using indices
data[0] = 10;
data[1] = 20;
data[2] = 30;
data[3] = 40;
data[4] = 50;

// Print individual elements
System.out.println(data[0]);
System.out.println(data[2]);
System.out.println(data[4]);

// %% [markdown]
// ### Reminder: Zero-Based Indexing
//
// The first element is always at index `0`.
//
// This often causes off-by-one errors in beginner code but you all know this already from Pythn.
//
// Remember:
// - First element → index `0`
// - Last element → index `length - 1`

// %%
// Demonstrating zero-based indexing
int[] values = new int[3];

values[0] = 5;
values[1] = 10;
values[2] = 15;

System.out.println(values[0]); // first element
System.out.println(values[2]); // last element

// %% [markdown]
// ### Array Length
//
// Every array in Java has a built-in property called `length`.
//
// This tells us how many elements the array can store.

// %%
int[] samples = new int[4];

System.out.println(samples.length);
//this prints the length!

// %% [markdown]
// The `length` property is extremely important.
//
// It allows us to:
// - avoid hard-coding numbers
// - write loops that adapt automatically to array size
// - prevent errors

// %%
// Array index out of bounds example
int[] data = new int[3];

// Valid indices: 0, 1, 2
data[3] = 99; // ERROR

// %% [markdown]
// This causes an **ArrayIndexOutOfBoundsException**.
//
// Why?
//
// The array has length 3, so valid indices are:
// - 0
// - 1
// - 2
//
// Index 3 does not exist.

// %%
// Simple example showing you how to use length in a loop
int[] data = new int[3];

data[0] = 7;
data[1] = 14;
data[2] = 21;

for (int i = 0; i < data.length; i++) {
    System.out.println(data[i]);
}

// %% [markdown]
// ### Key Points
//
// - Array indices start at **0**
// - Last index is `length - 1`
// - Accessing an invalid index causes a runtime error
// - Always use `array.length` in loops
// - This is identical to Python list indexing — just stricter

// %% [markdown]
// ## 2.4 Initialising Arrays
//
// So far, we have created arrays and then filled them **one element at a time**.
//
// Java provides several ways to initialise arrays, depending on what you know in advance.
//
// We will look at:
// - default initialisation
// - manual assignment
// - array literals
// - initialising arrays using loops
//
// ### Default Initialisation
//
// We learned already above that when an array is created, Java automatically fills it with default values.
//
// For numeric types:
// - `int` → 0
// - `double` → 0.0
//
// For booleans:
// - `boolean` → false
//
// For reference types:
// - `String` → null
//
// ### Manual Assignment
//
// We can explicitly assign values to individual elements using indices.

// %%
// Manual assignment as before using one index at a time: SLOW!
int[] data = new int[4];

data[0] = 2;
data[1] = 4;
data[2] = 6;
data[3] = 8;

for (int i = 0; i < data.length; i++) {
    System.out.println(data[i]);
}

// %% [markdown]
// This approach is clear but does not scale well for large arrays.
//
// ### Array Literals (One-Line Initialisation)
//
// If you already know the values, Java allows you to initialise an array in one line.

// %%
// Array literal: FAST!
int[] samples = {10, 20, 30, 40, 50};

for (int i = 0; i < samples.length; i++) {
    System.out.println(samples[i]);
}

// %% [markdown]
// Key points:
// - Java automatically determines the array size
// - You cannot change the size later!
//
// ### Using Loops to Initialise Arrays
//
// Loops are essential when:
// - values follow a pattern
// - values come from calculations
// - arrays are large

// %%
// Initialise array using a loop
int[] squares = new int[6];

for (int i = 0; i < squares.length; i++) {
    squares[i] = i * i;
}

// Now print with a loop
for (int i = 0; i < squares.length; i++) {
    System.out.println(squares[i]);
}

// %% [markdown]
// This is where arrays become powerful.
//
// Instead of writing many assignments, we describe a rule - and then use a loop with that rule in the body.

// %% [markdown]
// ### Common Mistake: Mixing Declaration Styles
//
// You cannot use an array literal without declaring the array at the same time.

// %%
// This will throw an error
int[] values;
values = {1, 2, 3}; // ERROR

// %% [markdown]
// This is not allowed because Java requires the array size or values at creation time.

// %%
// Correct usage
int[] values = {1, 2, 3};
System.out.println(values.length);

// %% [markdown]
// ### Key Points
//
// - Arrays are automatically initialised with default values
// - You can assign elements manually using indices
// - Array literals allow one-line initialisation
// - Loops are the most scalable way to fill arrays
// - Array size is fixed at creation time

// %% [markdown]
// ## 2.5 Arrays and Loops — Processing Data
//
// As you know already from Python, arrays become truly useful when combined with loops.
//
// A loop allows us to:
// - visit every element in an array
// - apply the same operation to all values
// - compute meaningful results from raw data
//
// This is the foundation of **algorithms**.

// %% [markdown]
// ### Iterating Over an Array
//
// The most common pattern is a `for` loop that runs from:
// - index `0`
// - up to (but not including) `array.length`
//
// ### Computing the Sum of an Array
//
// A very common algorithm is summing values.

// %%
// Sum all elements in an array
int[] readings = {4, 7, 1, 9, 3};
int sum = 0;

for (int i = 0; i < readings.length; i++) {
    sum = sum + readings[i];
}

System.out.println("Sum = " + sum);

// %%
// Exercise: Write code to get the average value of all elements in an array

double[] samples = {2.0, 4.0, 6.0, 8.0};
// Notice we used double for accuracy when getting an average!

// Finish the code
// hint: divide by `samples.length`, not a hard-coded number

// %% [markdown]
// This pattern appears everywhere in engineering and science.
//
// Algorithm structure:
// 1. initialise an accumulator
// 2. loop over the array
// 3. update the accumulator
//
// Actually, we can say that many different looping algorithms fall into a small number of classes....

// %% [markdown]
// ## 2.6 Algorithm Patterns with Arrays
//
// Up to now, we have learned:
//
// - how to create arrays
// - how to access elements
// - how to loop through them
//
// Now we move to something more important:
//
// > recognising **algorithm patterns**.
//
// In engineering and computing, many problems use the same small set of ideas over and over again.
//
// When you learn to recognise these patterns, programming becomes much easier.
//
// In this section we will study the most common patterns:
//
// - Accumulator pattern
// - Comparison pattern
// - Counting pattern
// - Search pattern
// - Transformation pattern

// %% [markdown]
// ### 2.6.1 Accumulator Pattern (Sum and Average)
//
// The **accumulator pattern** is used when we want to combine many values into one result.
//
// Typical examples:
//
// - total energy
// - sum of measurements
// - average voltage
// - total distance
//
// The structure is always:
//
// 1. create a variable to hold the result
// 2. loop over the array
// 3. update the variable each iteration
//
// You can see code examples of this type above for computing the sum and average of an array - there is no need for more examples!

// %% [markdown]
// ### 2.6.2 Comparison Pattern (Max and Min)
//
// Another very common algorithm compares values to find:
//
// - largest value
// - smallest value
// - best measurement
// - worst case
//
// The idea:
//
// 1. Assume the first element is the best candidate
// 2. Compare all remaining elements
// 3. Replace when a better one is found

// %%
// Example: Find maximum value (Comparison pattern)

int[] values = {12, 5, 27, 9, 3};

// /1. Assume the first element is the best candidate
int max = values[0];

//2. Compare all remaining elements
for (int i = 1; i < values.length; i++) {
    if (values[i] > max) {
        // 3. Replace when a better one is found
        max = values[i];
    }
}

System.out.println("Max = " + max);

// %%
// Exercise: Complete the minimum-value algorithm

double[] values = {12.1, 5.0, 27.3, 27.1, 3.1, 2.9};

double min = values[0];


// Fill in the missing code



System.out.println(min);

// %% [markdown]
// ### 2.6.3 Counting Pattern
//
// Sometimes we do not want the values themselves — we want to know **how many** meet a condition.
//
// Examples:
//
// - number of temperatures above a limit
// - number of failed tests
// - number of sensors active
//
// Structure:
//
// 1. start a counter at zero
// 2. loop through the array
// 3. increase the counter when condition is true

// %%
// Example: Count numbers greater than 10

int[] data = {4, 12, 7, 19, 3, 15};

// 1. start a counter at zero  
int count = 0;

// 2. loop through the array  
for (int i = 0; i < data.length; i++) {
    if (data[i] > 10) {
        // 3. increase the counter when condition is true
        count++;
    }
}

System.out.println("Count = " + count);

// %%
// Exercise: Count how many values are even

int[] numbers = {2, 5, 8, 11, 14, 17, 20};

int count = 0;


// Insert code here




System.out.println(count);
// Out:
// 0

// %% [markdown]
// ### 2.6.4 Search Pattern
//
// Searching is one of the most important algorithm ideas.
//
// Goal:
//
// > determine whether a value exists in the array.
//
// We often use:
//
// 1. Something to search for
// 2. A boolean variable that we set to `false` initially
// 3. A loop to search over
// 4. `break` to stop early if we find it

// %%
// Example: Search for a target value

int[] data = {5, 8, 2, 9, 4};

// 1. Something to search for
int target = 9;

// 2. A boolean variable that we set to `false` initially
boolean found = false;

//3. A loop to search over 
for (int i = 0; i < data.length; i++) {
    if (data[i] == target) {
        found = true;
        break; // 4. `break` to stop early if we find it
    }
}

System.out.println(found);

// %%
// Exercise: Complete the search algorithm

int[] values = {3, 6, 9, 12, 15};

int target = 7;
boolean found = false;

for (int i = 0; i < values.length; i++) {

    // TODO: check for target
    // TODO: set found = true
    // TODO: break

}

System.out.println(found);

// %% [markdown]
// ### 2.6.5 Transformation Pattern
//
// Sometimes we want to **modify** every element.
//
// Examples:
//
// - scaling signals
// - converting units
// - applying calibration factors
//
// Structure:
//
// loop over array and assign back into the same element.

// %%
// Example: Multiply every element by 2

int[] data = {1, 2, 3, 4, 5};

for (int i = 0; i < data.length; i++) {
    data[i] = data[i] * 2;
}

for (int i = 0; i < data.length; i++) {
    System.out.println(data[i]);
}

// %%
// Exercise: Convert Celsius to Fahrenheit for every element
// F = C * 9/5 + 32

double[] tempC = {0, 10, 20, 30};

for (int i = 0; i < tempC.length; i++) {

    // TODO: apply conversion formula

}

for (int i = 0; i < tempC.length; i++) {
    System.out.println(tempC[i]);
}

// %% [markdown]
// ### Key Ideas from Algorithm Patterns
//
// You should now recognise five core patterns:
//
// - **Accumulator** → combine values
// - **Comparison** → find best or worst
// - **Counting** → count matches
// - **Search** → check existence
// - **Transformation** → modify all values
//
// These patterns appear again and again in engineering software.
//
// Arrays + loops + these patterns = the foundation of algorithms.

// %% [markdown]
// ## 2.7 Reading User Input (Scanner)
//
// Up to now, all of our programs used values that were already written in the code.
//
// Real programs often need to **read input from the user**.
//
// In Java, we use a class called `Scanner` to do this.
//
// We must first:
// 1. import the Scanner class
// 2. create a Scanner object
// 3. call methods to read values
//
// The basic idea is:
// ```java
// import java.util.Scanner;
//
// Scanner input = new Scanner(System.in);
// ```
//
// This tells Java:
// - listen to keyboard input
// - allow us to read values typed by the user
//
// In the code below you can see how to input
// - a single word (a String up to the first space ` `) using `next()`
// - a full line (also a String but including the spaces using `nextLine()`
// - an int using `nextInt()`
// - a double using `nextDouble()`

// %%
// Scanner example: reading different input types

import java.util.Scanner;

// 1. Create Scanner object
Scanner input = new Scanner(System.in);

// ----- Read a single word -----
System.out.print("Enter a single word: ");
String word = input.next();
System.out.println("You entered (word): " + word);

// ----- Read a full line -----
System.out.print("Enter a full sentence: ");
String line = input.nextLine();
System.out.println("You entered (line): " + line);

// ----- Read an int -----
System.out.print("Enter an integer: ");
int number = input.nextInt();
System.out.println("You entered (int): " + number);

// ----- Read a double -----
System.out.print("Enter a decimal number: ");
double value = input.nextDouble();
System.out.println("You entered (double): " + value);

// %% [markdown]
// ## 2.8 Chapter Summary
//
// In this chapter you learned:
//
// ### Arrays
// - fixed-size collections of values
// - zero-based indexing
// - `.length` property
// - multiple ways to initialise arrays
//
// ### Arrays + Loops
// - process data efficiently
// - avoid repetitive code
//
// ### Algorithm Patterns
// - accumulator
// - comparison
// - counting
// - search
// - transformation
//
// ### Scanner Input
// - read integers, doubles and strings from the user
// - interactive programs are now possible
//
// You now know enough to build simple data-processing programs.
//
// Make sure to try to do the exercise below before reading the next chapter!

// %%
// Exercise 1: Create an int array of size 5 and print its length.

// %%
// Exercise 2: Create a double array and assign values manually.

// %%
// Exercise 3: Print all elements using a for loop.

// %%
// Exercise 4: Print all elements using a while loop.

// %%
// Exercise 5: Create an array using an array literal.

// %%
// Exercise 6: Compute the sum of an array.

// %%
// Exercise 8: Find the maximum value.

// %%
// Exercise 9: Find the minimum value.

// %%
// Exercise 10: Count how many numbers are even.

// %%
// Exercise 11: Search for a value in an array.

// %%
// Exercise 12: Count values greater than 50.

// %%
// Exercise 13: Multiply all elements by 3.

// %%
// Exercise 14: Convert Celsius array to Fahrenheit.

// %%
// Exercise 15: Check if ALL values are positive.

// %%
// Exercise 16: Read one int using Scanner and print it.

// %%
// Exercise 17: Read a double and print its square.

// %%
// Exercise 18: Read a name and print a greeting.

// %%
// Exercise 19: Use Scanner to fill an array of 5 ints.

// %%
// Exercise 20: Read 5 numbers and print their average.
